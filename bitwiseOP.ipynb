# %%
a=int(input("enter a"))
b=int(input("enter b"))
print(a | b)
print(a & b)
print(a ^ b)
# Out:
# enter a 3
# enter b 6
# 7
# 2
# 5

# %%
a = 5
b = 3
print(a & b)
print(a | b)
print(a ^ b)
# Out:
# 1
# 7
# 6
