# %%
## relational operator
a=20
b=30
print(a > b)
print(a < b)
print(a == b)
print(a !=b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
a=int(input("enter a"))
b=int(input("enter b"))
print(a > b)
print(a < b)
print(a == b)
print(a !=b)
print(a >= b)
print(a <= b)
# Out:
# enter a 10
# enter b 30
# False
# True
# False
# True
# False
# True
