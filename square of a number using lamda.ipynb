# %%
##square of a number using lamda
square=lambda x: x*x
n=int(input("enter"))
square(n)
# Out:
# enter 4
# 16

# %%
square=lambda x :x*x
n=int(input("enter"))
print(square(n))
# Out:
# enter 5
# 25
