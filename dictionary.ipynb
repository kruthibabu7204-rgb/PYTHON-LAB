# %%
#dictionary
student={
    "name":"kruthi",
    "age":21,
    "subjects":["IT","maths"]
}
print("dictionary:",student)
# Out:
# dictionary: {'name': 'kruthi', 'age': 21, 'subjects': ['IT', 'maths']}

# %%
#employe dictionary
employee={
    "emp name":"sahana",
    "id":10,
    "dept":"IT",
    "salary":["100000"]
}
print("dictionary:",employee)
# Out:
# dictionary: {'emp name': 'sahana', 'id': 10, 'dept': 'IT', 'salary': ['100000']}

# %%
print("name:",student.get("name"))
# Out:
# name: kruthi

# %%
student["age"]=22
student["grade"]=A
print("dictionary:",student)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 student["age"]=22
# ----> 2 student["grade"]=A
#       3 print("dictionary:",student)
#
# NameError: name 'A' is not defined
