# %%
#program to find sum 2 numbers using funtions
def sum(a,b):
    return a+b
x=sum(5,10)
print(x)
# Out:
# 15

# %%
def sum(a,b):
    return a+b
a=int(input("enter a:"))
b=int(input("enter b:"))
print("sum=",a+b)
# Out:
# enter a: 10
# enter b: 50
# sum= 60

# %%
def mult(a,b):
    return a*b
a=int(input("enter a:"))
b=int(input("enter b:"))
print("mult=",a*b)
# Out:
# enter a: 3
# enter b: 5
# mult= 15

# %%
def sum(a,b):
    return a+b
a=int(input("enter a"))
b=int(input("enter b"))
x= sum (a,b)
print("sum=",x)
# Out:
# enter a 3
# enter b 4
# sum= 7
