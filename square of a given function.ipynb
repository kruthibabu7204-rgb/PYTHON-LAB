# %%
#square of a given function
def square(x):
    return x*x
n=int(input("enter"))
print(square(n))
# Out:
# enter 5
# 25

# %%
def square(x):
    return x*x
n=int(input("enter"))
print(square(n))
# Out:
# enter 3
# 9
