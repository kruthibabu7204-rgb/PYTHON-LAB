# %%
#find max of 3 numbers using max and without using max function
def max(a,b,c):
    if a>b and b>c:
        print("a is maximum")
    elif b>a and b>c:
        print("b is maximum")
    else:
        print("c is maximum")
a=int(input("enter a:"))
b=int(input("enter b:"))
c=int(input("enter c:"))
max(a,b,c)
# Out:
# enter a: 3
# enter b: 5
# enter c: 4
# b is maximum

# %%
#find max of 3 numbers without using max function 
def maximum(a,b,c):
    return max(a,b,c)
x=maximum(5,3,4)
print("maximum",x)
# Out:
# c is maximum
# maximum None

# %%
def maximum(a,b,c):
    if a>b and b>c:
        return a
    elif b>c:
        return b
    else:
        return c
x=maximum(3,4,5)
print(x)
# Out:
# 5
