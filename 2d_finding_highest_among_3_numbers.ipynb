# %%
a=int(input("enter a"))
b=int(input("enter b"))
c=int(input("enter c"))
if a>b and a>c:
    print("a is a large");
elif b>c:
    print("b is a larger");
else:
    print("c is a largest");
# Out:
# enter a 45
# enter b 65
# enter c 30
# b is a larger
